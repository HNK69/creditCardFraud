# %% [markdown]
# # Phase 1 — Dataset Understanding
#
# Objective:
# Understand the structure, features, target variable, class distribution,
# data types, missing values, duplicates, and numerical statistics
# before performing any preprocessing or modeling.
